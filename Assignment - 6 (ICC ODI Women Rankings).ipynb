# %% [markdown]
# # Scraping Data of ODI Ranks and Player Ranks using Beautifulsoup from ICC-Cricket Website

# %%
#importing the required libraries

from bs4 import BeautifulSoup
import requests

# %%
#ODI Women's Rankings

page1 = requests.get("https://www.icc-cricket.com/rankings/womens/team-rankings/odi")
page1
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page1.content)
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="ICC Ranking for ODI teams International Cricket Council" name="twitter:title"/>
#   <meta content="website" property="og:type"/>
#   <meta content="summary_large_image" property="twitter:card"/>
#   <meta content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
#   <meta content="@icc" property="twitter:site"/>
#   <meta content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
#   <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
#   <meta content="ICC Ranking for ODI teams International Cricket Council" property="og:title"/>
# ...

# %%
ODI_Teams1= soup.find_all('td', class_='rankings-block__banner--team-name')
ODI_Teams1
# Out:
# [<td class="rankings-block__banner--team-name">
#  <span class="flag-30 rankings-block__banner--flag AUS"></span>
#  <span class="u-hide-phablet">Australia</span>
#  <span class="u-show-phablet">AUS</span>
#  </td>]

# %%
ODI_Teams_list = []

for i in ODI_Teams1:
     for j in i.find_all("span", class_= 'u-hide-phablet'):
            ODI_Teams_list.append(j.text)

ODI_Teams_list
# Out:
# ['Australia']

# %%
ODI_Teams2 = soup.find_all('td', class_='table-body__cell rankings-table__team')
ODI_Teams2
# Out:
# [<td class="table-body__cell rankings-table__team">
#  <span class="flag-15 table-body_logo SA"></span>
#  <span class="u-hide-phablet">South Africa</span>
#  <span class="u-show-phablet">SA</span>
#  </td>,
#  <td class="table-body__cell rankings-table__team">
#  <span class="flag-15 table-body_logo ENG"></span>
#  <span class="u-hide-phablet">England</span>
#  <span class="u-show-phablet">ENG</span>
#  </td>,
#  <td class="table-body__cell rankings-table__team">
#  <span class="flag-15 table-body_logo IND"></span>
#  <span class="u-hide-phablet">India</span>
#  <span class="u-show-phablet">IND</span>
#  </td>,
#  <td class="table-body__cell rankings-table__team">
#  <span class="flag-15 table-body_logo NZ"></span>
#  <span class="u-hide-phablet">New Zealand</span>
#  <span class="u-show-phablet">NZ</span>
#  </td>,
#  <td class="table-body__cell rankings-table__team">
#  <span class="flag-15 table-body_logo WI"></span>
#  <span class="u-hide-phablet">West Indies</span>
# ...

# %%
for i in ODI_Teams2[0:9]:
     for j in i.find_all("span", class_= 'u-hide-phablet'):
            ODI_Teams_list.append(j.text)

ODI_Teams_list
# Out:
# ['Australia',
#  'South Africa',
#  'England',
#  'India',
#  'New Zealand',
#  'West Indies',
#  'Pakistan',
#  'Bangladesh',
#  'Sri Lanka',
#  'Ireland']

# %%
Matches1 = soup.find_all('td' ,class_="rankings-block__banner--matches")
Matches1
# Out:
# [<td class="rankings-block__banner--matches">18</td>]

# %%
ODI_Matches_list = []

for i in Matches1:
     ODI_Matches_list.append(i.text)

ODI_Matches_list
# Out:
# ['18']

# %%
Points1 = soup.find_all('td' ,class_="rankings-block__banner--points")
Points1
# Out:
# [<td class="rankings-block__banner--points">2,955</td>]

# %%
ODI_Points_list = []

for i in Points1:
     ODI_Points_list.append(i.text)

ODI_Points_list
# Out:
# ['2,955']

# %%
Matches2 = soup.find_all('td', class_="table-body__cell u-center-text")
Matches2
# Out:
# [<td class="table-body__cell u-center-text">24</td>,
#  <td class="table-body__cell u-center-text">2,828</td>,
#  <td class="table-body__cell u-center-text">17</td>,
#  <td class="table-body__cell u-center-text">1,993</td>,
#  <td class="table-body__cell u-center-text">20</td>,
#  <td class="table-body__cell u-center-text">2,226</td>,
#  <td class="table-body__cell u-center-text">21</td>,
#  <td class="table-body__cell u-center-text">1,947</td>,
#  <td class="table-body__cell u-center-text">12</td>,
#  <td class="table-body__cell u-center-text">1,025</td>,
#  <td class="table-body__cell u-center-text">15</td>,
#  <td class="table-body__cell u-center-text">1,101</td>,
#  <td class="table-body__cell u-center-text">5</td>,
#  <td class="table-body__cell u-center-text">306</td>,
#  <td class="table-body__cell u-center-text">11</td>,
#  <td class="table-body__cell u-center-text">519</td>,
#  <td class="table-body__cell u-center-text">2</td>,
# ...

# %%
R_l = []

for i in Matches2[0:18]:
    R_l.append(i.text.replace('\n','').strip())
R_l

for i in range(len(R_l)):
    if ( i%2 == 0):
        ODI_Matches_list.append(R_l[i])
    else:
        ODI_Points_list.append(R_l[i])

# %%
ODI_Matches_list
# Out:
# ['18', '24', '17', '20', '21', '12', '15', '5', '11', '2']

# %%
ODI_Points_list
# Out:
# ['2,955',
#  '2,828',
#  '1,993',
#  '2,226',
#  '1,947',
#  '1,025',
#  '1,101',
#  '306',
#  '519',
#  '25']

# %%
Ratings1 = soup.find_all('td', class_="rankings-block__banner--rating u-text-right")
Ratings1
# Out:
# [<td class="rankings-block__banner--rating u-text-right">
#                              164
#                              <span class="circle-branding circle-branding--top"></span>
#  <span class="circle-branding circle-branding--bottom"></span>
#  </td>]

# %%
Ratings2 = soup.find_all('td', class_="table-body__cell u-text-right rating")
Ratings2
# Out:
# [<td class="table-body__cell u-text-right rating">118</td>,
#  <td class="table-body__cell u-text-right rating">117</td>,
#  <td class="table-body__cell u-text-right rating">111</td>,
#  <td class="table-body__cell u-text-right rating">93</td>,
#  <td class="table-body__cell u-text-right rating">85</td>,
#  <td class="table-body__cell u-text-right rating">73</td>,
#  <td class="table-body__cell u-text-right rating">61</td>,
#  <td class="table-body__cell u-text-right rating">47</td>,
#  <td class="table-body__cell u-text-right rating">13</td>]

# %%
ODI_Ratings = []

for i in Ratings1:
    ODI_Ratings.append(i.text.replace('\n','').strip())

for i in Ratings2[0:9]:
    ODI_Ratings.append(i.text.replace('\n','').strip())

ODI_Ratings
# Out:
# ['164', '118', '117', '111', '93', '85', '73', '61', '47', '13']

# %%
print(len(ODI_Teams_list), len(ODI_Matches_list), len(ODI_Points_list), len(ODI_Ratings))
# Out:
# 10 10 10 10

# %%
import pandas as pd

ODI_Womens_Cricket=pd.DataFrame({})

ODI_Womens_Cricket['Team'] = ODI_Teams_list
ODI_Womens_Cricket['Matches'] = ODI_Matches_list
ODI_Womens_Cricket['Points'] = ODI_Points_list 
ODI_Womens_Cricket['Rating'] = ODI_Ratings

ODI_Womens_Cricket
# Out:
#            Team Matches Points Rating
# 0     Australia      18  2,955    164
# 1  South Africa      24  2,828    118
# 2       England      17  1,993    117
# 3         India      20  2,226    111
# 4   New Zealand      21  1,947     93
# 5   West Indies      12  1,025     85
# 6      Pakistan      15  1,101     73
# 7    Bangladesh       5    306     61
# 8     Sri Lanka      11    519     47
# 9       Ireland       2     25     13

# %%
#Top 10 ODI Batswomen

page2 = requests.get("https://www.icc-cricket.com/rankings/womens/player-rankings/odi/batting")
page2
# Out:
# <Response [200]>

# %%
soup2 = BeautifulSoup(page2.content)
print(soup2.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="Live Cricket Scores &amp; News International Cricket Council" name="twitter:title"/>
#   <meta content="website" property="og:type"/>
#   <meta content="summary_large_image" property="twitter:card"/>
#   <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="description"/>
#   <meta content="@icc" property="twitter:site"/>
#   <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="twitter:description"/>
#   <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
#   <meta content="Live Cricket Scores &amp; News International Cricket Council" property="og:title"/>
# ...

# %%
Players = soup2.find_all('div', class_="rankings-block__banner--name-large")
Players
# Out:
# [<div class="rankings-block__banner--name-large">Tammy Beaumont</div>]

# %%
Players2 = soup2.find_all('td', class_='table-body__cell rankings-table__name name')
Players2
# Out:
# [<td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/1785">Lizelle Lee</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/466">Alyssa Healy</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/573">Stafanie Taylor</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/469">Meg Lanning</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/487">Amy Satterthwaite</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/1809">Smriti Mandhana</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/558">Mithali Raj</a>
#  </td>,
# ...

# %%
Players_list = []

for i in Players:
     Players_list.append(i.text)
        
for i in Players2[0:9]:
     for j in i.find_all("a"):
            Players_list.append(j.text)
            
Players_list
# Out:
# ['Tammy Beaumont',
#  'Lizelle Lee',
#  'Alyssa Healy',
#  'Stafanie Taylor',
#  'Meg Lanning',
#  'Amy Satterthwaite',
#  'Smriti Mandhana',
#  'Mithali Raj',
#  'Natalie Sciver',
#  'Laura Wolvaardt']

# %%
Team1 = soup2.find_all('div', class_="rankings-block__banner--nationality")
Team1
# Out:
# [<div class="rankings-block__banner--nationality">
#  <div class="flag-15 ENG"></div>
#  <span class="rankings-block__banner--nation"></span>ENG
#                      </div>]

# %%
Team2 = soup2.find_all('span', class_="table-body__logo-text")
Team2
# Out:
# [<span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">WI</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">NZ</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">ENG</span>,
#  <span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">SL</span>,
#  <span class="table-body__logo-text">ENG</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">NZ</span>,
#  <span class="table-body__logo-text">NZ</span>,
# ...

# %%
Teams_list = []

for i in Team1:
     Teams_list.append(i.text.replace('\n','').strip())
        
for i in Team2[0:9]:
    Teams_list.append(i.text.replace('\n','').strip())

Teams_list
# Out:
# ['ENG', 'SA', 'AUS', 'WI', 'AUS', 'NZ', 'IND', 'IND', 'ENG', 'SA']

# %%
Rating1 = soup2.find_all('div', class_="rankings-block__banner--rating")
Rating1
# Out:
# [<div class="rankings-block__banner--rating">765</div>]

# %%
Rating2 = soup2.find_all('td', class_="table-body__cell rating")
Rating2
# Out:
# [<td class="table-body__cell rating">758</td>,
#  <td class="table-body__cell rating">756</td>,
#  <td class="table-body__cell rating">746</td>,
#  <td class="table-body__cell rating">723</td>,
#  <td class="table-body__cell rating">715</td>,
#  <td class="table-body__cell rating">710</td>,
#  <td class="table-body__cell rating">709</td>,
#  <td class="table-body__cell rating">685</td>,
#  <td class="table-body__cell rating">683</td>,
#  <td class="table-body__cell rating">679</td>,
#  <td class="table-body__cell rating">667</td>,
#  <td class="table-body__cell rating">666</td>,
#  <td class="table-body__cell rating">657</td>,
#  <td class="table-body__cell rating">636</td>,
#  <td class="table-body__cell rating">620</td>,
#  <td class="table-body__cell rating">600</td>,
#  <td class="table-body__cell rating">593</td>,
#  <td class="table-body__cell rating">577</td>,
#  <td class="table-body__cell rating">573</td>,
#  <td class="table-body__cell rating">568</td>,
# ...

# %%
Ratings_list = []

for i in Rating1:
     Ratings_list.append(i.text.replace('\n','').strip())
        
for i in Rating2[0:9]:
    Ratings_list.append(i.text.replace('\n','').strip())

Ratings_list
# Out:
# ['765', '758', '756', '746', '723', '715', '710', '709', '685', '683']

# %%
Record1 = soup2.find_all('span', class_="rankings-block__career-best-text")
Record1
# Out:
# [<span class="rankings-block__career-best-text">
#                                  765 v New Zealand, 28/02/2021
#                          </span>]

# %%
Record2 = soup2.find_all('td', class_="table-body__cell u-text-right u-hide-phablet")
Record2
# Out:
# [<td class="table-body__cell u-text-right u-hide-phablet">
#                                  773 v India, 14/03/2021
#                          </td>,
#  <td class="table-body__cell u-text-right u-hide-phablet">
#                                  756 v New Zealand, 10/04/2021
#                          </td>,
#  <td class="table-body__cell u-text-right u-hide-phablet">
#                                  765 v India, 02/03/2012
#                          </td>,
#  <td class="table-body__cell u-text-right u-hide-phablet">
#                                  834 v New Zealand, 24/02/2016
#                          </td>,
#  <td class="table-body__cell u-text-right u-hide-phablet">
#                                  756 v Australia, 02/03/2017
#                          </td>,
#  <td class="table-body__cell u-text-right u-hide-phablet">
#                                  797 v England, 28/02/2019
#                          </td>,
# ...

# %%
Records_list = []

for i in Record1:
     Records_list.append(i.text.replace('\n','').strip())
        
for i in Record2[0:9]:
    Records_list.append(i.text.replace('\n','').strip())

Records_list
# Out:
# ['765 v New Zealand, 28/02/2021',
#  '773 v India, 14/03/2021',
#  '756 v New Zealand, 10/04/2021',
#  '765 v India, 02/03/2012',
#  '834 v New Zealand, 24/02/2016',
#  '756 v Australia, 02/03/2017',
#  '797 v England, 28/02/2019',
#  '839 v Australia, 24/12/2004',
#  '712 v India, 25/02/2019',
#  '725 v India, 07/03/2021']

# %%
print(len(Players_list), len(Teams_list), len(Ratings_list), len(Records_list))
# Out:
# 10 10 10 10

# %%
import pandas as pd

ODI_Batting_Women=pd.DataFrame({})

ODI_Batting_Women['Player'] = Players_list
ODI_Batting_Women['Team'] = Teams_list
ODI_Batting_Women['Rating'] = Ratings_list 
ODI_Batting_Women['Career_Best_Rating'] = Records_list

ODI_Batting_Women
# Out:
#               Player Team Rating             Career_Best_Rating
# 0     Tammy Beaumont  ENG    765  765 v New Zealand, 28/02/2021
# 1        Lizelle Lee   SA    758        773 v India, 14/03/2021
# 2       Alyssa Healy  AUS    756  756 v New Zealand, 10/04/2021
# 3    Stafanie Taylor   WI    746        765 v India, 02/03/2012
# 4        Meg Lanning  AUS    723  834 v New Zealand, 24/02/2016
# 5  Amy Satterthwaite   NZ    715    756 v Australia, 02/03/2017
# 6    Smriti Mandhana  IND    710      797 v England, 28/02/2019
# 7        Mithali Raj  IND    709    839 v Australia, 24/12/2004
# 8     Natalie Sciver  ENG    685        712 v India, 25/02/2019
# 9    Laura Wolvaardt   SA    683        725 v India, 07/03/2021

# %%
#Top 10 Women ODI All-Rounders

page3 = requests.get("https://www.icc-cricket.com/rankings/womens/player-rankings/odi/all-rounder")
page3
# Out:
# <Response [200]>

# %%
soup3 = BeautifulSoup(page3.content)
print(soup3.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="Live Cricket Scores &amp; News International Cricket Council" name="twitter:title"/>
#   <meta content="website" property="og:type"/>
#   <meta content="summary_large_image" property="twitter:card"/>
#   <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="description"/>
#   <meta content="@icc" property="twitter:site"/>
#   <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="twitter:description"/>
#   <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
#   <meta content="Live Cricket Scores &amp; News International Cricket Council" property="og:title"/>
# ...

# %%
Players = soup3.find_all('div', class_="rankings-block__banner--name-large")
Players
# Out:
# [<div class="rankings-block__banner--name-large">Marizanne Kapp</div>]

# %%
Players2 = soup3.find_all('td', class_='table-body__cell rankings-table__name name')
Players2
# Out:
# [<td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/471">Ellyse Perry</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/573">Stafanie Taylor</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/1800">Natalie Sciver</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/3192">Deepti Sharma</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/468">Jess Jonassen</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/4128">Ashleigh Gardner</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/430">Dane van Niekerk</a>
#  </td>,
# ...

# %%
Players_list = []

for i in Players:
     Players_list.append(i.text)
        
for i in Players2[0:9]:
     for j in i.find_all("a"):
            Players_list.append(j.text)
            
Players_list
# Out:
# ['Marizanne Kapp',
#  'Ellyse Perry',
#  'Stafanie Taylor',
#  'Natalie Sciver',
#  'Deepti Sharma',
#  'Jess Jonassen',
#  'Ashleigh Gardner',
#  'Dane van Niekerk',
#  'Sophie Devine',
#  'Amelia Kerr']

# %%
Team1 = soup3.find_all('div', class_="rankings-block__banner--nationality")
Team1
# Out:
# [<div class="rankings-block__banner--nationality">
#  <div class="flag-15 SA"></div>
#  <span class="rankings-block__banner--nation"></span>SA
#                      </div>]

# %%
Team2 = soup3.find_all('span', class_="table-body__logo-text")
Team2
# Out:
# [<span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">WI</span>,
#  <span class="table-body__logo-text">ENG</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">NZ</span>,
#  <span class="table-body__logo-text">NZ</span>,
#  <span class="table-body__logo-text">ENG</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">ENG</span>,
#  <span class="table-body__logo-text">BAN</span>,
#  <span class="table-body__logo-text">WI</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">SL</span>,
#  <span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">IND</span>]

# %%
Teams_list = []

for i in Team1:
     Teams_list.append(i.text.replace('\n','').strip())
        
for i in Team2[0:9]:
    Teams_list.append(i.text.replace('\n','').strip())

Teams_list
# Out:
# ['SA', 'AUS', 'WI', 'ENG', 'IND', 'AUS', 'AUS', 'SA', 'NZ', 'NZ']

# %%
Rating1 = soup3.find_all('div', class_="rankings-block__banner--rating")
Rating1
# Out:
# [<div class="rankings-block__banner--rating">418</div>]

# %%
Rating2 = soup3.find_all('td', class_="table-body__cell rating")
Rating2
# Out:
# [<td class="table-body__cell rating">418</td>,
#  <td class="table-body__cell rating">410</td>,
#  <td class="table-body__cell rating">349</td>,
#  <td class="table-body__cell rating">343</td>,
#  <td class="table-body__cell rating">307</td>,
#  <td class="table-body__cell rating">252</td>,
#  <td class="table-body__cell rating">243</td>,
#  <td class="table-body__cell rating">242</td>,
#  <td class="table-body__cell rating">236</td>,
#  <td class="table-body__cell rating">236</td>,
#  <td class="table-body__cell rating">204</td>,
#  <td class="table-body__cell rating">200</td>,
#  <td class="table-body__cell rating">189</td>,
#  <td class="table-body__cell rating">179</td>,
#  <td class="table-body__cell rating">176</td>,
#  <td class="table-body__cell rating">167</td>,
#  <td class="table-body__cell rating">164</td>,
#  <td class="table-body__cell rating">153</td>,
#  <td class="table-body__cell rating">151</td>]

# %%
Ratings_list = []

for i in Rating1:
     Ratings_list.append(i.text.replace('\n','').strip())
        
for i in Rating2[0:9]:
    Ratings_list.append(i.text.replace('\n','').strip())

Ratings_list
# Out:
# ['418', '418', '410', '349', '343', '307', '252', '243', '242', '236']

# %%
Record1 = soup3.find_all('span', class_="rankings-block__career-best-text")
Record1
# Out:
# [<span class="rankings-block__career-best-text">
#                                  418 v India, 17/03/2021
#                          </span>]

# %%
Record2 = soup3.find_all('td', class_="table-body__cell u-text-right u-hide-phablet")
Record2
# Out:
# [<td class="table-body__cell u-text-right u-hide-phablet">
#                                  548 v West Indies, 11/09/2019
#                          </td>,
#  <td class="table-body__cell u-text-right u-hide-phablet">
#                                  559 v New Zealand, 10/10/2013
#                          </td>,
#  <td class="table-body__cell u-text-right u-hide-phablet">
#                                  349 v New Zealand, 28/02/2021
#                          </td>,
#  <td class="table-body__cell u-text-right u-hide-phablet">
#                                  397 v South Africa, 09/10/2019
#                          </td>,
#  <td class="table-body__cell u-text-right u-hide-phablet">
#                                  308 v West Indies, 11/09/2019
#                          </td>,
#  <td class="table-body__cell u-text-right u-hide-phablet">
#                                  256 v New Zealand, 04/04/2021
#                          </td>,
# ...

# %%
Records_list = []

for i in Record1:
     Records_list.append(i.text.replace('\n','').strip())
        
for i in Record2[0:9]:
    Records_list.append(i.text.replace('\n','').strip())

Records_list
# Out:
# ['418 v India, 17/03/2021',
#  '548 v West Indies, 11/09/2019',
#  '559 v New Zealand, 10/10/2013',
#  '349 v New Zealand, 28/02/2021',
#  '397 v South Africa, 09/10/2019',
#  '308 v West Indies, 11/09/2019',
#  '256 v New Zealand, 04/04/2021',
#  '421 v Sri Lanka, 11/02/2019',
#  '305 v Australia, 05/10/2020',
#  '247 v Australia, 07/04/2021']

# %%
print(len(Players_list), len(Teams_list), len(Ratings_list), len(Records_list))
# Out:
# 10 10 10 10

# %%
import pandas as pd

ODI_All_Rounder_Women=pd.DataFrame({})

ODI_All_Rounder_Women['Player'] = Players_list
ODI_All_Rounder_Women['Team'] = Teams_list
ODI_All_Rounder_Women['Rating'] = Ratings_list 
ODI_All_Rounder_Women['Career_Best_Rating'] = Records_list

ODI_All_Rounder_Women
# Out:
#              Player Team Rating              Career_Best_Rating
# 0    Marizanne Kapp   SA    418         418 v India, 17/03/2021
# 1      Ellyse Perry  AUS    418   548 v West Indies, 11/09/2019
# 2   Stafanie Taylor   WI    410   559 v New Zealand, 10/10/2013
# 3    Natalie Sciver  ENG    349   349 v New Zealand, 28/02/2021
# 4     Deepti Sharma  IND    343  397 v South Africa, 09/10/2019
# 5     Jess Jonassen  AUS    307   308 v West Indies, 11/09/2019
# 6  Ashleigh Gardner  AUS    252   256 v New Zealand, 04/04/2021
# 7  Dane van Niekerk   SA    243     421 v Sri Lanka, 11/02/2019
# 8     Sophie Devine   NZ    242     305 v Australia, 05/10/2020
# 9       Amelia Kerr   NZ    236     247 v Australia, 07/04/2021
